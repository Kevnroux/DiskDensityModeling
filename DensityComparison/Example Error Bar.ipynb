# %%
import matplotlib.pyplot as plt

# %%
bins = [16,16.5,17,17.5,18,18.5,19,19.5,20,20.5,21,21.5,22]

height = [723.375,626.98,530.586,875.221,1219.86,1295.37,1370.89,1036.22,701.547,3095.43,5489.31,4278,3066.68]

err_com = [4572.080351402485,5987.419826511818,7794.648226186112,10140.16152897793,12450.34676318515,15985.591684696721,20830.698961566555,22295.69036163774,23721.28787197518,28619.894948383797,19886.135892830534,18492.122758967584,8379.974997344543]
err_num = [7210.951737788337,19765.006425798234,-75031.54781865436,53416.843184628306,25955.936060409207,105574.55776501817,-56982.742545080415,-18892.92973570996,-11923.218253564948,18898.886460002297,5083.444184498587,5478.359520933814,3296.116408217105]

plt.title("PannStars B:-12.5, L:30")
plt.xlabel("Magnitude")
plt.ylabel("Star Counts")
plt.scatter(bins, height)
plt.show()

plt.title("Error_Anal.")
plt.xlabel("Magnitude")
plt.ylabel("Star Counts")
plt.scatter(bins, err_com)
plt.show()

plt.title("Error_Num.")
plt.xlabel("Magnitude")
plt.ylabel("Star Counts")
plt.scatter(bins, err_num)
plt.show()
